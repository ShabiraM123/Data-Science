# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew

# %%
data=pd.read_csv('Diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.shape
# Out:
# (768, 9)

# %%
data.size
# Out:
# 6912

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Conclusion :
# 1. Each column contains 768 values
# 2. Mean value identified for each column
# 3. Std is close to zero indecates that data points close to mean,std greater than zero indecates that data points far from mean
# 4.

# %%
data.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
print(skew(data, axis=0,bias=True))
# Out:
# [ 0.89991194  0.17341396 -1.84000523  0.10915876  2.26781046 -0.42814328
#   1.9161592   1.12738926  0.6337757 ]

# %%
for i in data.columns:
    sns.distplot(data[i])
    plt.show()

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
pic=plt.figure(figsize=(14,7),dpi=(300))
sns.heatmap(data.corr(),annot=True)

# %%
sns.pairplot(data=data, vars=['Age','Pregnancies','BloodPressure','SkinThickness','BMI'],hue='Outcome')

# %%
#Relationship between Age and Diabets
sns.catplot(x='Outcome',y='Age',kind='boxen',data=data)

# %% [markdown]
# Most of diabets can be seen in between the age of 30 and 45

# %%
sns.relplot(x='BloodPressure',y='Age',hue='Outcome',data=data)

# %%
sns.relplot(x='BMI',y='Age',hue='Outcome',data=data)

# %%
sns.relplot(x='DiabetesPedigreeFunction',y='Age',hue='Outcome',data=data)

# %% [markdown]
# It's important for individuals to be aware of the increased risk of diabetes as they age, especially if they have other risk factors like family history, obesity, or an unhealthy lifestyle.
# Age, blood pressure, and diabetes are interconnected through a complex web of risk factors and biological mechanisms. Understanding and managing these factors are crucial for maintaining overall health and preventing complications associated with diabetes and high blood pressure. Individuals should work closely with healthcare providers to develop personalized strategies for prevention and management based on their specific circumstances.

# %%
sns.catplot(x='Outcome',y='Pregnancies',kind='boxen',data=data)

# %%
sns.relplot(x='DiabetesPedigreeFunction',y='Pregnancies',hue='Outcome',data=data)

# %% [markdown]
# no of pregnancies and diabetes are connected each other. If they had diabetes during their first pregnancy,may have higher chance of getting  diabetes in their future pregnancies.

# %%
sns.relplot(x='BMI',y='Pregnancies',hue='Outcome',data=data)

# %% [markdown]
# High BMI, especially if it falls into the overweight or obese categories, is a significant risk factor for the development of gestational diabetes during pregnancy.
# Gestational diabetes is a type of diabetes that develops during pregnancy. Women with a higher BMI are more likely to develop gestational diabetes because excess body weight can lead to insulin resistance, where the body's cells do not respond well to insulin.

# %%
sns.relplot(x='BloodPressure',y='Pregnancies',hue='Outcome',data=data)

# %% [markdown]
# Women with gestational diabetes may be at a higher risk of developing gestational hypertension, and vice versa. These conditions can coexist and share common risk factors, such as obesity and insulin resistance.

# %%
sns.relplot(x='Insulin',y='Pregnancies',hue='Outcome',data=data)

# %% [markdown]
# he type of diabetes a woman has (e.g., type 1 diabetes, type 2 diabetes, or gestational diabetes) plays a significant role in determining insulin requirements during pregnancy.
# Weight gain during pregnancy can influence insulin needs. Women who gain more weight during pregnancy may require higher insulin doses.

# %%
sns.catplot(x='Outcome',y='BloodPressure',kind='boxen',data=data)

# %%
sns.relplot(x='BMI',y='BloodPressure',hue='Outcome',data=data)

# %% [markdown]
# -Blood Pressure and diabetes can be coexist and influence each other.
# -Obesity, especially abdominal obesity, can lead to various metabolic changes, including increased production of inflammatory substances, hormonal imbalances, and increased fluid volume, all of which can contribute to elevated blood pressure.
# -The combination of a high BMI and insulin resistance, common in overweight and obese individuals, can have a synergistic effect, further increasing the risk of both type 2 diabetes and hypertension. This underscores the importance of managing BMI as a preventive measure for these conditions.
#
# -It's important to note that while BMI is a useful tool for assessing weight-related health risks, it doesn't provide a complete picture of an individual's health. Other factors, such as genetics, family history, diet, physical activity, and overall lifestyle, also influence the development of diabetes and high blood pressure.

# %%
sns.catplot(x='Outcome',y='Insulin',kind='boxen',data=data)

# %% [markdown]
# insulin deficiency is the one of the major fact of getting diabetes .if it is in the range of 0-200 may have higher chance of getting diabetes.

# %%
sns.catplot(x='Outcome',y='BMI',kind='boxen',data=data)

# %% [markdown]
# Higher chance getting diabetes ,if their BMI in the range of 30-40

# %%
sns.catplot(x='Outcome',y='DiabetesPedigreeFunction',kind='boxen',data=data)

# %% [markdown]
# It is a hereditary risk of diabetes.It is lying in between in the range of 0.25-0.75

# %% [markdown]
# # Conclusion
# -Main Factors that increase the diabetes are high BMI,Insulin resistance,Overweight and Family history .
# -The women who experienced diabetes in their previous pregnancies, may have higher chance of getting  diabetes in their future    pregnancies.
# -BloodPressure and diabetes are also co-related.
# People with hypertension have an elevated risk of developing diabetes compared to those with normal blood pressure.
